# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakesh-DaSilva/ait/blob/main/testday01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://news.mit.edu/sites/default/files/images/202103/M87-lo-polarimetric-average.png -O m87.png
# Out:
# --2023-02-15 22:03:41--  https://news.mit.edu/sites/default/files/images/202103/M87-lo-polarimetric-average.png
# Resolving news.mit.edu (news.mit.edu)... 23.185.0.4, 2620:12a:8001::4, 2620:12a:8000::4
# Connecting to news.mit.edu (news.mit.edu)|23.185.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 383654 (375K) [image/png]
# Saving to: ‘m87.png’
#
# m87.png             100%[===================>] 374.66K  --.-KB/s    in 0.01s
#
# 2023-02-15 22:03:41 (26.3 MB/s) - ‘m87.png’ saved [383654/383654]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('m87.png')
imgplot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

input_image = Image.open("m87.png")
pixel_map = input_image.load()

#CHANGED PIXEL TO WHITE SINCE ALREADY BLACK
pixel_map[30, 30] = (255,255,255)
input_image.save("changed.png", format="png")

# %%
img = mpimg.imread('changed.png')
imgplot = plt.imshow(img)
plt.show()
